# %% [markdown]
# - Name: Deepanshi
# - Roll No.: MDS202416
# - Assignment 2

# %% [markdown]
# 1. Imports, Setup, and Gitignore

# %%
# !pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (1.1.1)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install "dvc[gdrive]"

import pandas as pd
import urllib.request
import zipfile
import os
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.model_selection import train_test_split

# Download necessary NLTK data
nltk.download('stopwords')
print("Libraries imported and NLTK data downloaded.")

# Initialize Stemmer and Stopwords
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: dvc[gdrive] in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (3.66.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (25.3.0)
# Requirement already satisfied: celery in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (5.6.2)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.4.6)
# Requirement already satisfied: configobj>=5.0.9 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (5.0.9)
# Requirement already satisfied: distro>=1.3 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (1.9.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (2.2.0)
# Requirement already satisfied: dulwich in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (1.0.0)
# Requirement already satisfied: dvc-data<3.19.0,>=3.18.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (3.18.2)
# Requirement already satisfied: dvc-http>=2.29.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (2.32.0)
# Requirement already satisfied: dvc-objects in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (5.2.0)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (1.0.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.21 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.22.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.40.2)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.4.2)
# Requirement already satisfied: flufl.lock<10,>=8.1.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (9.0.0)
# Requirement already satisfied: fsspec>=2024.2.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (2025.9.0)
# Requirement already satisfied: funcy>=1.14 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.8)
# Requirement already satisfied: gto<2,>=1.6.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (1.9.0)
# Requirement already satisfied: hydra-core>=1.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (1.3.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.0.10)
# Requirement already satisfied: kombu in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (5.6.2)
# Requirement already satisfied: networkx>=2.5 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (3.5)
# Requirement already satisfied: omegaconf in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (2.3.0)
# Requirement already satisfied: packaging>=19 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (25.0)
# Requirement already satisfied: pathspec<1,>=0.10.3 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.12.1)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (4.4.0)
# Requirement already satisfied: psutil>=5.8 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (7.0.0)
# Requirement already satisfied: pydot>=1.2.4 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (4.0.1)
# Requirement already satisfied: pygtrie>=2.3.2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (2.5.0)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (3.2.5)
# Requirement already satisfied: requests>=2.22 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (2.32.5)
# Requirement already satisfied: rich>=12 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (14.1.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.19.1)
# Requirement already satisfied: scmrepo<4,>=3.5.2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (3.6.1)
# Requirement already satisfied: shortuuid>=0.5 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (1.0.13)
# Requirement already satisfied: shtab<2,>=1.3.4 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (1.8.0)
# Requirement already satisfied: tabulate>=0.8.7 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.9.0)
# Requirement already satisfied: tomlkit>=0.11.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.14.0)
# Requirement already satisfied: tqdm<5,>=4.63.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (4.67.1)
# Requirement already satisfied: voluptuous>=0.11.7 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (0.16.0)
# Requirement already satisfied: zc.lockfile>=1.2.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (4.0)
# Requirement already satisfied: dvc-gdrive<4,>=3 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc[gdrive]) (3.0.1)
# Requirement already satisfied: dictdiffer>=0.8.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc[gdrive]) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc[gdrive]) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc[gdrive]) (0.11.2)
# Requirement already satisfied: orjson<4,>=3 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc-data<3.19.0,>=3.18.0->dvc[gdrive]) (3.11.7)
# Requirement already satisfied: pydrive2>=1.19.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.21.3)
# Requirement already satisfied: pywin32>=225 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dvc-task<1,>=0.3.0->dvc[gdrive]) (311)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from celery->dvc[gdrive]) (4.2.4)
# Requirement already satisfied: vine<6.0,>=5.1.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from celery->dvc[gdrive]) (5.1.0)
# Requirement already satisfied: click<9.0,>=8.1.2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from celery->dvc[gdrive]) (8.2.1)
# Requirement already satisfied: click-didyoumean>=0.3.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from celery->dvc[gdrive]) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from celery->dvc[gdrive]) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from celery->dvc[gdrive]) (1.1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from celery->dvc[gdrive]) (2.9.0.post0)
# Requirement already satisfied: tzlocal in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from celery->dvc[gdrive]) (5.3.1)
# Requirement already satisfied: six<2.0,>=1.12 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from flatten-dict<1,>=0.4.1->dvc[gdrive]) (1.17.0)
# Requirement already satisfied: atpublic in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from flufl.lock<10,>=8.1.0->dvc[gdrive]) (7.0.0)
# Requirement already satisfied: entrypoints in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from gto<2,>=1.6.0->dvc[gdrive]) (0.4)
# Requirement already satisfied: pydantic>=2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from gto<2,>=1.6.0->dvc[gdrive]) (2.11.7)
# Requirement already satisfied: pydantic-settings>=2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from gto<2,>=1.6.0->dvc[gdrive]) (2.10.1)
# Requirement already satisfied: semver>=2.13.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from gto<2,>=1.6.0->dvc[gdrive]) (3.0.4)
# Requirement already satisfied: typer>=0.4.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from gto<2,>=1.6.0->dvc[gdrive]) (0.16.1)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from kombu->dvc[gdrive]) (5.3.1)
# Requirement already satisfied: tzdata>=2025.2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from kombu->dvc[gdrive]) (2025.2)
# Requirement already satisfied: gitpython>3 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from scmrepo<4,>=3.5.2->dvc[gdrive]) (3.1.46)
# Requirement already satisfied: pygit2>=1.14.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from scmrepo<4,>=3.5.2->dvc[gdrive]) (1.19.1)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from scmrepo<4,>=3.5.2->dvc[gdrive]) (2.22.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from scmrepo<4,>=3.5.2->dvc[gdrive]) (2.9.1)
# Requirement already satisfied: cryptography>=39.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc[gdrive]) (43.0.3)
# Requirement already satisfied: typing_extensions>=4.0.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc[gdrive]) (4.15.0)
# Requirement already satisfied: aiohttp in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (3.13.0)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from click-repl>=0.2.0->celery->dvc[gdrive]) (3.0.52)
# Requirement already satisfied: cffi>=1.12 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from cryptography>=39.0->asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc[gdrive]) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from cffi>=1.12->cryptography>=39.0->asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc[gdrive]) (3.0)
# Requirement already satisfied: urllib3>=2.2.2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from dulwich->dvc[gdrive]) (2.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from gitpython>3->scmrepo<4,>=3.5.2->dvc[gdrive]) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3.5.2->dvc[gdrive]) (5.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from hydra-core>=1.1->dvc[gdrive]) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from omegaconf->dvc[gdrive]) (6.0.2)
# Requirement already satisfied: appdirs in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from iterative-telemetry>=0.0.7->dvc[gdrive]) (1.4.4)
# Requirement already satisfied: filelock in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from iterative-telemetry>=0.0.7->dvc[gdrive]) (3.19.1)
# Requirement already satisfied: wcwidth in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc[gdrive]) (0.2.13)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc[gdrive]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc[gdrive]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from pydantic>=2->gto<2,>=1.6.0->dvc[gdrive]) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from pydantic-settings>=2->gto<2,>=1.6.0->dvc[gdrive]) (1.1.1)
# Requirement already satisfied: google-api-python-client>=1.12.5 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.187.0)
# Requirement already satisfied: oauth2client>=4.0.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.1.3)
# Requirement already satisfied: pyOpenSSL<=24.2.1,>=19.1.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (24.2.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from requests>=2.22->dvc[gdrive]) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from requests>=2.22->dvc[gdrive]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from requests>=2.22->dvc[gdrive]) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from rich>=12->dvc[gdrive]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from rich>=12->dvc[gdrive]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=12->dvc[gdrive]) (0.1.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc[gdrive]) (1.5.4)
# Requirement already satisfied: setuptools in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from zc.lockfile>=1.2.1->dvc[gdrive]) (80.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\deepanshi\appdata\roaming\python\python313\site-packages (from aiohttp->aiohttp-retry>=2.5.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (1.22.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Libraries imported and NLTK data downloaded.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Deepanshi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import os
from dotenv import load_dotenv
load_dotenv()
client_id = os.getenv("GDRIVE_CLIENT_ID")
client_secret = os.getenv("GDRIVE_CLIENT_SECRET")

# %%
# Create or update .gitignore file 
# This prevents Git from tracking the heavy data files directly.
with open(".gitignore", "w") as f:
    f.write("""
.ipynb_checkpoints/
sms_spam_collection.zip
.env
""")
print(".gitignore created.")
# Out:
# .gitignore created.

# %% [markdown]
# 2. Download and Load Dataset

# %%
# --- 1. Download the dataset from UCI ---
url = "https://archive.ics.uci.edu/static/public/228/sms+spam+collection.zip"
zip_path = "sms_spam_collection.zip"

# %%
# Download the zip file if it doesn't exist
if not os.path.exists(zip_path):
    urllib.request.urlretrieve(url, zip_path)
    print("Dataset downloaded.")
# Out:
# Dataset downloaded.

# %%
# --- 2. Unzip the file ---
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(".")

# %%
# --- 3. Load into Pandas ---
# The UCI dataset is tab-separated with no header.
# We manually assign the columns 'label' and 'text'.
df = pd.read_csv('SMSSpamCollection', sep='\t', header=None, names=['label', 'text'])

# %%
print(f"Dataset shape: {df.shape}")
print(df.head())
# Out:
# Dataset shape: (5572, 2)
#   label                                               text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# 3. Basic EDA & Preprocessing

# %%
print("Class distribution:")
print(df["label"].value_counts())
print("\nMissing values:")
print(df.isnull().sum())
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Class distribution:
# label
# ham     4825
# spam     747
# Name: count, dtype: int64
#
# Missing values:
# label    0
# text     0
# dtype: int64
#
# Duplicate rows: 403

# %%
# Preprocessing Pipeline 
def clean_text(text):
    """
    Preprocessing pipeline to normalize SMS text:
    1. Lowercase: Normalize case sensitivity.
    2. Regex: Remove special characters/numbers (keep only alphabets).
    3. Tokenize: Split string into a list of words.
    4. Remove Stopwords: Filter out common words (e.g., 'the', 'is').
    5. Stemming: Reduce words to their root form (e.g., 'calling' -> 'call').
    """
    if not isinstance(text, str):
        return ""
        
    # 1. Lowercase
    text = text.lower()
    
    # 2. Remove non-alphabetic characters (keep spaces)
    text = re.sub(r'[^a-z\s]', '', text)
    
    # 3. Tokenize
    words = text.split()
    
    # 4. & 5. Remove stopwords and Stem
    cleaned_words = [stemmer.stem(word) for word in words if word not in stop_words]
    
    return " ".join(cleaned_words)

# %% [markdown]
# 4. Apply Cleaning + Save Raw Data

# %%
print(f"Original shape: {df.shape}")
# Out:
# Original shape: (5572, 2)

# %%
# --- 1. Drop Duplicates ---
# Critical for SMS datasets as duplicate messages can cause data leakage 
# between train and test sets.
df = df.drop_duplicates(keep='first')
print(f"Shape after dropping duplicates: {df.shape}")
# Out:
# Shape after dropping duplicates: (5169, 2)

# %%
# --- 2. Encode Labels ---
# Map string labels to binary integers: Spam = 1, Ham = 0
df['target'] = df['label'].map({'spam': 1, 'ham': 0})

# %%
# --- 3. Apply Text Cleaning ---
# Apply the clean_text function to create the feature column
df['clean_text'] = df['text'].apply(clean_text)

# %%
# Remove any empty rows created by aggressive cleaning (e.g., messages with only special chars)
df = df[df['clean_text'].str.len() > 0]

print("Preprocessing complete.")
# Out:
# Preprocessing complete.

# %%
print("After preprocessing:", df.shape)
# Out:
# After preprocessing: (5068, 2)

# %%
# Save Raw Data
df = df[['target', 'clean_text']] # Keep only necessary columns
df.to_csv("raw_data.csv", index=False)
print("Preprocessing complete. raw_data.csv saved.")
# Out:
# Preprocessing complete. raw_data.csv saved.

# %% [markdown]
# 5. Git/DVC Init

# %%
# 4. Initialize Git & DVC, and define split function
# !git init
# !dvc init
# Out:
# Reinitialized existing Git repository in D:/CMI Courses/Applied ML/Assignment2/.git/
# ERROR: failed to initiate DVC - '.dvc' exists. Use `-f` to force.

# %%
# !git add .gitignore .dvc/config
# !git commit -m "Initialize Git and DVC"
# Out:
# [detached HEAD f5a468e] Initialize Git and DVC
#  2 files changed, 6 insertions(+), 2 deletions(-)

# %% [markdown]
# 6. Version 1 (Seed 21)

# %%
train_val, test = train_test_split(
    df,
    test_size=0.15,
    random_state=21,
    stratify=df['target']
)

val_size = 0.15 / 0.85

train, val = train_test_split(
    train_val,
    test_size=val_size,
    random_state=21,
    stratify=train_val['target']
)

# %%
train.to_csv("train.csv", index=False)
val.to_csv("validation.csv", index=False)
test.to_csv("test.csv", index=False)

print("Split with seed 21 saved.")
# Out:
# Split with seed 21 saved.

# %%
print("=== Seed 21 Distribution ===")

print("\nTrain:")
print(train['target'].value_counts())

print("\nValidation:")
print(val['target'].value_counts())

print("\nTest:")
print(test['target'].value_counts())
# Out:
# === Seed 21 Distribution ===
#
# Train:
# target
# 0    3156
# 1     457
# Name: count, dtype: int64
#
# Validation:
# target
# 0    677
# 1     98
# Name: count, dtype: int64
#
# Test:
# target
# 0    677
# 1     98
# Name: count, dtype: int64

# %%
# !dvc add raw_data.csv train.csv validation.csv test.csv
# !git add raw_data.csv.dvc train.csv.dvc validation.csv.dvc test.csv.dvc
# !git commit -m "Version 1: Split with seed 21"
# Out:
# To track the changes with git, run:
#
# 	git add train.csv.dvc raw_data.csv.dvc test.csv.dvc validation.csv.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# [main 873224d] Version 1: Split with seed 21
#  4 files changed, 20 insertions(+)
#  create mode 100644 raw_data.csv.dvc
#  create mode 100644 test.csv.dvc
#  create mode 100644 train.csv.dvc
#  create mode 100644 validation.csv.dvc

# %%
# !git log
# Out:
# commit 873224d3df14076339ab01f466c905d389f035f2
# Author: deepSin <singladeepanshi6@gmail.com>
# Date:   Sun Feb 15 20:31:46 2026 +0530
#
#     Version 1: Split with seed 21
#
# commit 34ceb5cdc139a3a4e5e069f71b17681eccb3b774
# Author: deepSin <singladeepanshi6@gmail.com>
# Date:   Sun Feb 15 20:31:34 2026 +0530
#
#     Initialize Git and DVC

# %% [markdown]
# 7. Version 2 (Seed 77)

# %%
train_val, test = train_test_split(
    df,
    test_size=0.15,
    random_state=77,
    stratify=df['target']
)

# %%
val_size = 0.15 / 0.85

train, val = train_test_split(
    train_val,
    test_size=val_size,
    random_state=77,
    stratify=train_val['target']
)

# %%
train.to_csv("train.csv", index=False)
val.to_csv("validation.csv", index=False)
test.to_csv("test.csv", index=False)

print("Split with seed 77 saved.")
# Out:
# Split with seed 77 saved.

# %%
print("=== Seed 77 Distribution ===")

print("\nTrain:")
print(train['target'].value_counts())

print("\nValidation:")
print(val['target'].value_counts())

print("\nTest:")
print(test['target'].value_counts())
# Out:
# === Seed 77 Distribution ===
#
# Train:
# target
# 0    3156
# 1     457
# Name: count, dtype: int64
#
# Validation:
# target
# 0    677
# 1     98
# Name: count, dtype: int64
#
# Test:
# target
# 0    677
# 1     98
# Name: count, dtype: int64

# %%
# !dvc add train.csv validation.csv test.csv
# !git add train.csv.dvc validation.csv.dvc test.csv.dvc
# !git commit -m "Version 2: Updated split with seed 77"
# Out:
# To track the changes with git, run:
#
# 	git add train.csv.dvc validation.csv.dvc test.csv.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true
# ⠋ Checking graph
# [main 1713e5e] Version 2: Updated split with seed 77
#  3 files changed, 6 insertions(+), 6 deletions(-)

# %% [markdown]
# 8. Checking Out and Printing Distributions

# %%
# !git log --oneline
# Out:
# 1713e5e Version 2: Updated split with seed 77
# 873224d Version 1: Split with seed 21
# 34ceb5c Initialize Git and DVC

# %%
# !git log
# Out:
# commit 1713e5e1ae7478775c4c12e7d4c8068fd27206d2
# Author: deepSin <singladeepanshi6@gmail.com>
# Date:   Sun Feb 15 20:31:54 2026 +0530
#
#     Version 2: Updated split with seed 77
#
# commit 873224d3df14076339ab01f466c905d389f035f2
# Author: deepSin <singladeepanshi6@gmail.com>
# Date:   Sun Feb 15 20:31:46 2026 +0530
#
#     Version 1: Split with seed 21
#
# commit 34ceb5cdc139a3a4e5e069f71b17681eccb3b774
# Author: deepSin <singladeepanshi6@gmail.com>
# Date:   Sun Feb 15 20:31:34 2026 +0530
#
#     Initialize Git and DVC

# %%
# !git checkout HEAD~1
# !dvc checkout
# Out:
# Note: switching to 'HEAD~1'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 873224d Version 1: Split with seed 21
# M       test.csv
# M       train.csv
# M       validation.csv

# %%
print("=== Distribution for Version 1 (Seed 21) ===")
train_old = pd.read_csv("train.csv")
val_old = pd.read_csv("validation.csv")
test_old = pd.read_csv("test.csv")

print("Train distribution:")
print(train_old["target"].value_counts())

print("\nValidation distribution:")
print(val_old["target"].value_counts())

print("\nTest distribution:")
print(test_old["target"].value_counts())
# Out:
# === Distribution for Version 1 (Seed 21) ===
# Train distribution:
# target
# 0    3156
# 1     457
# Name: count, dtype: int64
#
# Validation distribution:
# target
# 0    677
# 1     98
# Name: count, dtype: int64
#
# Test distribution:
# target
# 0    677
# 1     98
# Name: count, dtype: int64

# %%
# Go back to the latest commit (Version 2)
# !git checkout main
# !dvc checkout
# Out:
# Previous HEAD position was 873224d Version 1: Split with seed 21
# Switched to branch 'main'
# M       test.csv
# M       train.csv
# M       validation.csv

# %%
print("=== Distribution for Version 2 (Seed 77) ===")
train_new = pd.read_csv("train.csv")
val_new = pd.read_csv("validation.csv")
test_new = pd.read_csv("test.csv")

print("Train distribution:")
print(train_new["target"].value_counts())

print("\nValidation distribution:")
print(val_new["target"].value_counts())

print("\nTest distribution:")
print(test_new["target"].value_counts())
# Out:
# === Distribution for Version 2 (Seed 77) ===
# Train distribution:
# target
# 0    3156
# 1     457
# Name: count, dtype: int64
#
# Validation distribution:
# target
# 0    677
# 1     98
# Name: count, dtype: int64
#
# Test distribution:
# target
# 0    677
# 1     98
# Name: count, dtype: int64

# %% [markdown]
# 9. Bonus- Google Drive Storage

# %%
# !dvc remote add -d myremote gdrive://1ZhdeoELGohWWqaw7WgTTM13OJ4fy3R8U
# Out:
# Setting 'myremote' as a default remote.

# %%
# !dvc remote modify myremote gdrive_client_id "{client_id}"
# !dvc remote modify myremote gdrive_client_secret "{client_secret}"

# %%
print("Credentials securely loaded from .env and applied to DVC!")
# Out:
# Credentials securely loaded from .env and applied to DVC!

# %%
import os

# DVC creates these files to prevent conflicts. If a process dies, they get stuck.
lock_files = [".dvc/tmp/rwlock", ".dvc/tmp/lock"]

for file in lock_files:
    if os.path.exists(file):
        os.remove(file)
        print(f"Removed stuck lock file: {file}")

print("DVC is unlocked and ready to go!")
# Out:
# Removed stuck lock file: .dvc/tmp/rwlock
# Removed stuck lock file: .dvc/tmp/lock
# DVC is unlocked and ready to go!

# %%
# !dvc push
# Out:
# Everything is up to date.

# %%
# !dvc remote list
# Out:
# myremote        gdrive://1ZhdeoELGohWWqaw7WgTTM13OJ4fy3R8U      (default)

# %%
# Checkout the PREVIOUS version (Seed 21) and push that to Google Drive as well
# !git checkout HEAD~1
# !dvc checkout
# !dvc push
# Out:
# M	.dvc/config
# Note: switching to 'HEAD~1'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 873224d Version 1: Split with seed 21
# M       test.csv
# M       train.csv
# M       validation.csv
# 3 files pushed

# %%
# Return to main branch
# !git checkout main
# !dvc checkout
print("Both versions successfully pushed to Google Drive!")
# Out:
# M	.dvc/config
# Previous HEAD position was 873224d Version 1: Split with seed 21
# Switched to branch 'main'
# M       test.csv
# M       train.csv
# M       validation.csv
# Both versions successfully pushed to Google Drive!

# %% [markdown]
# Summary:

# %% [markdown]
# 1. Data Cleaning & Processing: Ingested the raw SMS spam dataset and performed essential text preprocessing. This included standardizing the text into a clean format (clean_text) and encoding the spam/ham labels into a binary target variable for machine learning.
#
# 2. Simulating Data Shift: Split the processed data into Training, Validation, and Test sets. To rigorously test model robustness later, this splitting process was performed twice using two different random seeds (Seed 21 and Seed 77), creating two distinct versions of the dataset.
#
# 3. Data Version Control (DVC): Initialized DVC to track the heavy data files (train.csv, validation.csv, test.csv). Instead of bloating the Git repository with large CSVs, DVC created lightweight .dvc pointer files to track data changes.
#
# 4. Git Integration: Committed the .dvc files to Git, creating a clear, time-traversable history. Version 1 (Seed 21) and Version 2 (Seed 77) were saved as distinct commits in the Git timeline.
#
# 5. Remote Cloud Storage: Configured a secure Google Drive remote using a Google Cloud Service Account. The actual heavy CSV files were successfully pushed to the cloud (dvc push), ensuring the data was safely backed up and easily retrievable for the training pipeline.
